# %% [markdown]
# # Assignment 2

# %%
1.Question Using If else and Elif conditional statement to check reportcard.

# %%
score=int(input("Enter the score to checking result "))
# Out:
# Enter the score to checking result 22

# %%
if score>=33 and score<=45:
    print("pass as well as got C grade")
    
elif score<=33:
    print("Got Fail")
elif score>=45:
    print("Got B")
elif score>=80:
    print("Got A")
else:
    print("Got B+ grade")
# Out:
# Got Fail

# %% [markdown]
# Question 2. Print prime number in b/w 1 to 1000

# %%
#
lower=1
upper=1000

for n in range(lower,upper):
    
    if n%2==0:
        
        print("Not a Prime number")
else:
            print("Prime")
# Out:
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# Not a Prime number
# ...

# %% [markdown]
# 3.Question , Write a program to print table from 1 to 10 using nested for loop

# %%
for i in range(1,11):
    for j in range(1,11):
        s=i*j
        print("The table is",s)
# Out:
# The table is 1
# The table is 2
# The table is 3
# The table is 4
# The table is 5
# The table is 6
# The table is 7
# The table is 8
# The table is 9
# The table is 10
# The table is 2
# The table is 4
# The table is 6
# The table is 8
# The table is 10
# The table is 12
# The table is 14
# The table is 16
# The table is 18
# The table is 20
# The table is 3
# The table is 6
# The table is 9
# The table is 12
# The table is 15
# The table is 18
# The table is 21
# The table is 24
# The table is 27
# The table is 30
# The table is 4
# The table is 8
# The table is 12
# The table is 16
# The table is 20
# The table is 24
# The table is 28
# The table is 32
# The table is 36
# The table is 40
# The table is 5
# The table is 10
# The table is 15
# The table is 20
# The table is 25
# The table is 30
# The table is 35
# The table is 40
# The table is 45
# The table is 50
# The table is 6
# The table is 12
# The table is 18
# The table is 24
# The table is 30
# The table is 36
# ...

# %% [markdown]
# 4.Question WAP to print x numbers using While loop starting from 0 and take the i/p of x from the user

# %%
x=int("ENter the number to check prime or not")

# %%
n=0
i=2
while(i<=x//2):
    if(x%i==0):
        n=n+1
        break
        i=i+1
        if(n==0 and x!=1):
            print("prime number")
else:
    print("Not a prime number")

# %%
Sir ,I check this code it is still excuting/working in the diiferent editior but its not working here and not taking my inputs
